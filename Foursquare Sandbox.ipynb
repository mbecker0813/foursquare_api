# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


#!pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


#! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20201001'
LIMIT = 50
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID:
# CLIENT_SECRET:

# %%
address = '1401 Clark Ave, Saint Louis, MO'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 38.62680845 -90.20263932150607

# %%
search_query = 'Hotel'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Hotel .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=1E1TS1XS3FOSY5HQO0QABFG4LVTH1ZNA1XC0QRY2JI354ORT&client_secret=TV41VXNR4Z2I1IVSH53HPBOTD1O3LFOMROPDZJR3GNWGF2OE&ll=38.62680845,-90.20263932150607&v=20201001&query=Hotel&radius=5000&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f8f372bdc3fa014e6deb897'},
#  'response': {'venues': [{'id': '54aabce9498ee74ea1c8d10b',
#     'name': 'Red Lion Hotel St. Louis',
#     'location': {'address': '400 S 14th St',
#      'crossStreet': 'Spruce',
#      'lat': 38.62432564742862,
#      'lng': -90.20223371643416,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62432564742862,
#        'lng': -90.20223371643416}],
#      'distance': 278,
#      'postalCode': '63103',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['400 S 14th St (Spruce)',
#       'St Louis, MO 63103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '120295850'},
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '508de513e4b09f7bba74e3bb',
#     'name': 'St. Louis Union Station Hotel, Curio Collection by Hilton',
#     'location': {'address': '1820 Market St',
#      'lat': 38.6281661,
#      'lng': -90.2075881,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.6281661,
#        'lng': -90.2075881}],
#      'distance': 456,
#      'postalCode': '63103',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['1820 Market St',
#       'St Louis, MO 63103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '59e694bf98fbfc0ac5ddf8e9',
#     'name': 'Hotel Saint Louis, Autograph Collection',
#     'location': {'address': '705 Olive St',
#      'crossStreet': '7th Street',
#      'lat': 38.6284969,
#      'lng': -90.1916093,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.6284969,
#        'lng': -90.1916093}],
#      'distance': 977,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['705 Olive St (7th Street)',
#       'St Louis, MO 63101',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '50375451e4b0df99d53c13fe',
#     'name': 'Hotel El Pocho',
#     'location': {'address': 'Hirygoyen 600',
#      'lat': 38.62680659303982,
#      'lng': -90.20265057648547,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62680659303982,
#        'lng': -90.20265057648547}],
#      'distance': 1,
#      'postalCode': '63103',
#      'cc': 'US',
#      'city': 'Justo Darac',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['Hirygoyen 600',
#       'Justo Darac, MO 63103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4b0ff2aff964a520a36623e3',
#     'name': 'Four Seasons Hotel',
#     'location': {'address': '999 N 2nd St',
#      'crossStreet': 'at Carr St.',
#      'lat': 38.63372654049416,
#      'lng': -90.18499296083174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63372654049416,
#        'lng': -90.18499296083174}],
#      'distance': 1716,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['999 N 2nd St (at Carr St.)',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4b6b5c99f964a52081032ce3',
#     'name': 'Spa at Four Seasons Hotel St. Louis',
#     'location': {'address': '999 N 2nd St',
#      'lat': 38.63348919160805,
#      'lng': -90.18454150817425,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63348919160805,
#        'lng': -90.18454150817425}],
#      'distance': 1740,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['999 N 2nd St',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4acbc3f9f964a5207ec520e3',
#     'name': 'Lumiere Place Casino & Hotel',
#     'location': {'address': '999 N 2nd St',
#      'lat': 38.63318667,
#      'lng': -90.18533833,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63318667,
#        'lng': -90.18533833}],
#      'distance': 1663,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['999 N 2nd St',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d17c941735',
#       'name': 'Casino',
#       'pluralName': 'Casinos',
#       'shortName': 'Casino',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '46544983'},
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4acbc3f9f964a52078c520e3',
#     'name': 'Drury Plaza Hotel St. Louis At The Arch',
#     'location': {'address': '2 S 4th St',
#      'lat': 38.62484625528558,
#      'lng': -90.18898120932448,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62484625528558,
#        'lng': -90.18898120932448}],
#      'distance': 1207,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['2 S 4th St',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '5ca465cac5b11c002c010408',
#     'name': 'Hotel Indigo',
#     'location': {'address': '501 Olive St',
#      'lat': 38.62794,
#      'lng': -90.18932,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62794,
#        'lng': -90.18932}],
#      'distance': 1165,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['501 Olive St',
#       'St Louis, MO 63101',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '575265004'},
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4dc8c220e4cdf14b85507cef',
#     'name': 'Renaissance St. Louis Grand Hotel - Fitness Center',
#     'location': {'address': '800 Washington Ave',
#      'lat': 38.630498895524035,
#      'lng': -90.19172170957134,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.630498895524035,
#        'lng': -90.19172170957134}],
#      'distance': 1034,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['800 Washington Ave',
#       'St Louis, MO 63101',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4c2ab1888abca5938824ff1f',
#     'name': 'Millennium Hotel St. Louis',
#     'location': {'lat': 38.621267544260164,
#      'lng': -90.1914739412643,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.621267544260164,
#        'lng': -90.1914739412643}],
#      'distance': 1150,
#      'postalCode': '63102',
#      'cc': 'US',
#      'neighborhood': 'Downtown East',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO 63102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4c79c3f781bca09326b8fe14',
#     'name': 'Renaissance Grand Hotel Parking Garage',
#     'location': {'lat': 38.63039850763389,
#      'lng': -90.20255444918084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63039850763389,
#        'lng': -90.20255444918084}],
#      'distance': 399,
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO', 'United States']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '53f2954a498e248b534eda30',
#     'name': 'Magnolia Hotel',
#     'location': {'address': '421 North 8th Street',
#      'lat': 38.6300716,
#      'lng': -90.1919992,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.6300716,
#        'lng': -90.1919992}],
#      'distance': 994,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['421 North 8th Street',
#       'St Louis, MO 63101',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '5d11afbe96effb0023a494a4',
#     'name': 'The Last Hotel',
#     'location': {'address': '1501 Washington Ave',
#      'lat': 38.632729666315406,
#      'lng': -90.20054796197132,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.632729666315406,
#        'lng': -90.20054796197132}],
#      'distance': 683,
#      'postalCode': '63103',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['1501 Washington Ave',
#       'St Louis, MO 63103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '5b4106609411f2002cbf5295',
#     'name': 'Union Station Hotel Gift Shop',
#     'location': {'lat': 38.629135,
#      'lng': -90.207297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.629135,
#        'lng': -90.207297}],
#      'distance': 480,
#      'postalCode': '63103',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO 63103', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4ae5b3a5f964a52090a121e3',
#     'name': 'Data Carrier Hotel',
#     'location': {'address': '210 N Tucker Blvd',
#      'crossStreet': 'Pine',
#      'lat': 38.6296791871398,
#      'lng': -90.19714881612425,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.6296791871398,
#        'lng': -90.19714881612425}],
#      'distance': 574,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['210 N Tucker Blvd (Pine)',
#       'St Louis, MO 63101',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '5011702b45b09001ecec1f29',
#     'name': 'Ford Hotel Supply Co - St. Louis',
#     'location': {'address': '2204 N Broadway',
#      'lat': 38.649086838417865,
#      'lng': -90.18803358078003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.649086838417865,
#        'lng': -90.18803358078003}],
#      'distance': 2786,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['2204 N Broadway',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4fb15a5ce4b0fd09aa1850c2',
#     'name': 'cupples Ballroom Westin Hotel',
#     'location': {'lat': 38.6231803894043,
#      'lng': -90.19666290283203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.6231803894043,
#        'lng': -90.19666290283203}],
#      'distance': 658,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO 63102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '5e4361fcdfa35f0008124e83',
#     'name': 'The Last Hotel Gym',
#     'location': {'lat': 38.632717,
#      'lng': -90.200638,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.632717,
#        'lng': -90.200638}],
#      'distance': 680,
#      'postalCode': '63103',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO 63103', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4e3847a88877541e90edf963',
#     'name': 'Living At The Hotel Gibby',
#     'location': {'lat': 38.6304988,
#      'lng': -90.195995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.6304988,
#        'lng': -90.195995}],
#      'distance': 708,
#      'cc': 'US',
#      'state': 'Missouri',
#      'country': 'United States',
#      'formattedAddress': ['Missouri', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d18e941735',
#       'name': 'Comedy Club',
#       'pluralName': 'Comedy Clubs',
#       'shortName': 'Comedy Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/comedyclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '50e5053be4b0514cab710f41',
#     'name': 'Mark Twain Hotel',
#     'location': {'address': '205 N 9th St',
#      'crossStreet': 'Pine St',
#      'lat': 38.628448486328125,
#      'lng': -90.19450378417969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.628448486328125,
#        'lng': -90.19450378417969}],
#      'distance': 730,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['205 N 9th St (Pine St)',
#       'St Louis, MO 63101',
#       'United States']},
#     'categories': [{'id': '4f4530a74b9074f6e4fb0100',
#       'name': 'Boarding House',
#       'pluralName': 'Boarding Houses',
#       'shortName': 'Boarding',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4ea2bc8777c8d0ce5e0ed2ab',
#     'name': 'Hotel Fitness Center',
#     'location': {'lat': 38.6304160501076,
#      'lng': -90.19137326550168,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.6304160501076,
#        'lng': -90.19137326550168}],
#      'distance': 1058,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO 63101', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4f5d203fe4b0a61f4cab854a',
#     'name': 'Renaissance Hotel St. Louis Crystal Ballroom',
#     'location': {'lat': 38.630649179621535,
#      'lng': -90.19292919286315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.630649179621535,
#        'lng': -90.19292919286315}],
#      'distance': 946,
#      'cc': 'US',
#      'state': 'Missouri',
#      'country': 'United States',
#      'formattedAddress': ['Missouri', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '5756c5e3498eb346a8016811',
#     'name': 'Lennox Hotel 1929 portal',
#     'location': {'lat': 38.630929,
#      'lng': -90.192606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.630929,
#        'lng': -90.192606}],
#      'distance': 985,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO 63101', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4ed46bcc93ad512d8d68c0ab',
#     'name': 'AFA Annual Meeting (Renaissance St. Louis Grand Hotel)',
#     'location': {'address': '800 Washington Ave',
#      'crossStreet': '9th Street',
#      'lat': 38.630561,
#      'lng': -90.1922489,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.630561,
#        'lng': -90.1922489}],
#      'distance': 995,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['800 Washington Ave (9th Street)',
#       'St Louis, MO 63101',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '57da0008498ec00cda120d7d',
#     'name': 'Hotel Avyan',
#     'location': {'address': '2625 Lafayette Ave',
#      'lat': 38.615962982177734,
#      'lng': -90.22198486328125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.615962982177734,
#        'lng': -90.22198486328125}],
#      'distance': 2070,
#      'postalCode': '63104',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['2625 Lafayette Ave',
#       'St Louis, MO 63104',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '591673bad552c72b8cd36b0e',
#     'name': 'City Place Hotel',
#     'location': {'address': '200 N 4th St',
#      'lat': 38.627026,
#      'lng': -90.18738,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.627026,
#        'lng': -90.18738}],
#      'distance': 1327,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['200 N 4th St',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4b0f356af964a5206b6023e3',
#     'name': 'Hotel Indigo',
#     'location': {'address': '4630 Lindell Blvd',
#      'lat': 38.642669,
#      'lng': -90.260789,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.642669,
#        'lng': -90.260789}],
#      'distance': 5355,
#      'postalCode': '63108',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['4630 Lindell Blvd',
#       'St Louis, MO 63108',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4b4a4c3ef964a520cf8226e3',
#     'name': 'The Parkway Hotel',
#     'location': {'address': '4550 Forest Park Ave',
#      'crossStreet': 'at S Euclid Ave.',
#      'lat': 38.63868380115087,
#      'lng': -90.2617435484313,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63868380115087,
#        'lng': -90.2617435484313}],
#      'distance': 5306,
#      'postalCode': '63108',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['4550 Forest Park Ave (at S Euclid Ave.)',
#       'St Louis, MO 63108',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '5189449f498ecc6fb8dc3471',
#     'name': 'HoteLumière Atrium',
#     'location': {'address': '999 N 2nd St',
#      'lat': 38.63231867994509,
#      'lng': -90.18371809758652,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63231867994509,
#        'lng': -90.18371809758652}],
#      'distance': 1756,
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['999 N 2nd St', 'St Louis, IL', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4e11dedbaeb74afe60c0ab43',
#     'name': 'Millennium Hotel Cafe And Buffet',
#     'location': {'lat': 38.62285,
#      'lng': -90.1897009,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62285,
#        'lng': -90.1897009}],
#      'distance': 1208,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO 63102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4c66e172b80abe9a4a4acee5',
#     'name': 'Fitness Center at Millennium Hotel',
#     'location': {'address': '400 S 4th St',
#      'lat': 38.62125015258789,
#      'lng': -90.18982696533203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62125015258789,
#        'lng': -90.18982696533203}],
#      'distance': 1274,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['400 S 4th St',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4c3539ce66e40f471ff6ca8b',
#     'name': 'Millennium Hotel Outdoor Pool',
#     'location': {'address': '200 W 4th',
#      'lat': 38.62355695397472,
#      'lng': -90.18852699535137,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62355695397472,
#        'lng': -90.18852699535137}],
#      'distance': 1279,
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['200 W 4th', 'St Louis, MO', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4ce6b1a3e888f04dc799376b',
#     'name': 'Drury Plaza Hotel Exercise Room',
#     'location': {'address': '2-98 Memorial Dr',
#      'lat': 38.62463321318748,
#      'lng': -90.18833938681804,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62463321318748,
#        'lng': -90.18833938681804}],
#      'distance': 1266,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['2-98 Memorial Dr',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4df39d961f6e818dae014e80',
#     'name': 'Samuel Shephard Hotel',
#     'location': {'lat': 38.63647688711329,
#      'lng': -90.21400900745219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63647688711329,
#        'lng': -90.21400900745219}],
#      'distance': 1461,
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO', 'United States']},
#     'categories': [],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '5a1404928ad62e7497e0a279',
#     'name': 'Hampton Inn Hotel Pool',
#     'location': {'lat': 38.629753,
#      'lng': -90.184085,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.629753,
#        'lng': -90.184085}],
#      'distance': 1646,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO 63102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '53504da6498e406e709aa8b6',
#     'name': '8th Floor Lobby ~ Four Seasons Hotel',
#     'location': {'lat': 38.63347947877371,
#      'lng': -90.18459198228956,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63347947877371,
#        'lng': -90.18459198228956}],
#      'distance': 1736,
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '55135419498e3b5627966d1c',
#     'name': 'Four Seasons Hotel Fitness Center',
#     'location': {'lat': 38.633524,
#      'lng': -90.18443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.633524,
#        'lng': -90.18443}],
#      'distance': 1751,
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4fdbe627e4b0602ab5a063ee',
#     'name': 'four season hotel roof top',
#     'location': {'lat': 38.6335509373844,
#      'lng': -90.18491225910735,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.6335509373844,
#        'lng': -90.18491225910735}],
#      'distance': 1714,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO 63102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4df2308b3151247c51af65e0',
#     'name': 'Cabana 1, Sky Terrace at Four Seasons Hotel St. Louis',
#     'location': {'address': '999 N 2nd St',
#      'crossStreet': 'Carr Street',
#      'lat': 38.633969406269586,
#      'lng': -90.18417119979858,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.633969406269586,
#        'lng': -90.18417119979858}],
#      'distance': 1792,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['999 N 2nd St (Carr Street)',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4ea5fcd830f8a6425ee8bbd4',
#     'name': 'Four Seasons Hotel 6th Floor Lobby',
#     'location': {'lat': 38.63345126091753,
#      'lng': -90.18434971226729,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63345126091753,
#        'lng': -90.18434971226729}],
#      'distance': 1753,
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['St Louis, MO', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4d9b29fcc67f2c0f036248af',
#     'name': 'Hotel Ignacio',
#     'location': {'address': '3411 Olive St',
#      'lat': 38.63674444515303,
#      'lng': -90.22858106019467,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63674444515303,
#        'lng': -90.22858106019467}],
#      'distance': 2512,
#      'postalCode': '63103',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['3411 Olive St',
#       'St Louis, MO 63103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4c7f7576d860b60c37dc609d',
#     'name': 'Casino Queen Hotel',
#     'location': {'address': '200 Front St',
#      'lat': 38.62655457190104,
#      'lng': -90.17481708290828,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62655457190104,
#        'lng': -90.17481708290828}],
#      'distance': 2419,
#      'postalCode': '62201',
#      'cc': 'US',
#      'city': 'East Saint Louis',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['200 Front St',
#       'East Saint Louis, IL 62201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '5aa349efacc5f55cdf29c15e',
#     'name': 'Angad Arts Hotel',
#     'location': {'address': '3550 Samuel T Shepard Dr',
#      'lat': 38.63963001520621,
#      'lng': -90.23059967940033,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.63963001520621,
#        'lng': -90.23059967940033}],
#      'distance': 2819,
#      'postalCode': '63103',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['3550 Samuel T Shepard Dr',
#       'St Louis, MO 63103',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4af73b36f964a520780722e3',
#     'name': 'Hyatt Regency St. Louis At The Arch',
#     'location': {'address': '315 Chestnut St',
#      'lat': 38.6259076372355,
#      'lng': -90.187671482563,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.6259076372355,
#        'lng': -90.187671482563}],
#      'distance': 1305,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['315 Chestnut St',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1528303',
#      'url': 'https://www.grubhub.com/restaurant/the-arch-cafe-11-north-4th-street-st-louis/1528303?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1528303',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4acbc3f9f964a5207fc520e3',
#     'name': 'Hilton',
#     'location': {'address': '1 S Broadway',
#      'crossStreet': 'at Market St.',
#      'lat': 38.62513965275549,
#      'lng': -90.1909276843071,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62513965275549,
#        'lng': -90.1909276843071}],
#      'distance': 1035,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['1 S Broadway (at Market St.)',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4f436f7519834bc91f56d2a9',
#     'name': 'Ford Hotel Supply',
#     'location': {'address': '2204 N Broadway',
#      'lat': 38.64769595869986,
#      'lng': -90.18819296127688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.64769595869986,
#        'lng': -90.18819296127688}],
#      'distance': 2642,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['2204 N Broadway',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4ae84525f964a52068ae21e3',
#     'name': 'Marriott St. Louis Grand',
#     'location': {'address': '800 Washington Ave',
#      'crossStreet': 'at N 8th St',
#      'lat': 38.630542465206226,
#      'lng': -90.19190767965985,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.630542465206226,
#        'lng': -90.19190767965985}],
#      'distance': 1021,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['800 Washington Ave (at N 8th St)',
#       'St Louis, MO 63101',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '386729447'},
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4bb364ec14cfd13a16f315ab',
#     'name': 'Mahogany Grille & Lounge',
#     'location': {'address': '1019 Pine St',
#      'lat': 38.62860785859991,
#      'lng': -90.19569236719953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.62860785859991,
#        'lng': -90.19569236719953}],
#      'distance': 636,
#      'postalCode': '63101',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['1019 Pine St',
#       'St Louis, MO 63101',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False},
#    {'id': '4ae6f0a9f964a520a1a721e3',
#     'name': 'Starbucks',
#     'location': {'address': '315 Chestnut St',
#      'lat': 38.625811,
#      'lng': -90.187446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.625811,
#        'lng': -90.187446}],
#      'distance': 1325,
#      'postalCode': '63102',
#      'cc': 'US',
#      'city': 'St Louis',
#      'state': 'MO',
#      'country': 'United States',
#      'formattedAddress': ['315 Chestnut St',
#       'St Louis, MO 63102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1603221291',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /Users/michaelbecker/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id  \
# 0  54aabce9498ee74ea1c8d10b
# 1  508de513e4b09f7bba74e3bb
# 2  59e694bf98fbfc0ac5ddf8e9
# 3  50375451e4b0df99d53c13fe
# 4  4b0ff2aff964a520a36623e3
#
#                                                 name  \
# 0                           Red Lion Hotel St. Louis
# 1  St. Louis Union Station Hotel, Curio Collectio...
# 2            Hotel Saint Louis, Autograph Collection
# 3                                     Hotel El Pocho
# 4                                 Four Seasons Hotel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603221291    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603221291    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603221291    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603221291    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1603221291    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# 0    400 S 14th St               Spruce     38.624326    -90.202234
# 1   1820 Market St                  NaN     38.628166    -90.207588
# 2     705 Olive St           7th Street     38.628497    -90.191609
# 3    Hirygoyen 600                  NaN     38.626807    -90.202651
# 4     999 N 2nd St          at Carr St.     38.633727    -90.184993
#
#                              location.labeledLatLngs  ...  location.country  \
# 0  [{'label': 'display', 'lat': 38.62432564742862...  ...     United States
# 1  [{'label': 'display', 'lat': 38.6281661, 'lng'...  ...     United States
# 2  [{'label': 'display', 'lat': 38.6284969, 'lng'...  ...     United States
# 3  [{'label': 'display', 'lat': 38.62680659303982...  ...     United States
# 4  [{'label': 'display', 'lat': 38.63372654049416...  ...     United States
#
#                            location.formattedAddress venuePage.id  \
# 0  [400 S 14th St (Spruce), St Louis, MO 63103, U...    120295850
# 1  [1820 Market St, St Louis, MO 63103, United St...          NaN
# 2  [705 Olive St (7th Street), St Louis, MO 63101...          NaN
# 3  [Hirygoyen 600, Justo Darac, MO 63103, United ...          NaN
# 4  [999 N 2nd St (at Carr St.), St Louis, MO 6310...          NaN
#
#   location.neighborhood delivery.id delivery.url delivery.provider.name  \
# 0                   NaN         NaN          NaN                    NaN
# 1                   NaN         NaN          NaN                    NaN
# 2                   NaN         NaN          NaN                    NaN
# 3                   NaN         NaN          NaN                    NaN
# 4                   NaN         NaN          NaN                    NaN
#
#   delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#   delivery.provider.icon.name
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 25 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name             categories  \
# 0                            Red Lion Hotel St. Louis                  Hotel
# 1   St. Louis Union Station Hotel, Curio Collectio...                  Hotel
# 2             Hotel Saint Louis, Autograph Collection                  Hotel
# 3                                      Hotel El Pocho                  Hotel
# 4                                  Four Seasons Hotel                  Hotel
# 5                 Spa at Four Seasons Hotel St. Louis                    Spa
# 6                        Lumiere Place Casino & Hotel                 Casino
# 7             Drury Plaza Hotel St. Louis At The Arch                  Hotel
# 8                                        Hotel Indigo                  Hotel
# 9   Renaissance St. Louis Grand Hotel - Fitness Ce...   Gym / Fitness Center
# 10                         Millennium Hotel St. Louis                  Hotel
# 11             Renaissance Grand Hotel Parking Garage                Parking
# 12                                     Magnolia Hotel                  Hotel
# 13                                     The Last Hotel                  Hotel
# 14                      Union Station Hotel Gift Shop              Gift Shop
# 15                                 Data Carrier Hotel                   None
# 16                   Ford Hotel Supply Co - St. Louis     Miscellaneous Shop
# 17                      cupples Ballroom Westin Hotel              Hotel Bar
# 18                                 The Last Hotel Gym   Gym / Fitness Center
# 19                          Living At The Hotel Gibby            Comedy Club
# 20                                   Mark Twain Hotel         Boarding House
# 21                               Hotel Fitness Center                    Gym
# 22       Renaissance Hotel St. Louis Crystal Ballroom                  Hotel
# 23                           Lennox Hotel 1929 portal                  Hotel
# 24  AFA Annual Meeting (Renaissance St. Louis Gran...            Event Space
# 25                                        Hotel Avyan                  Hotel
# 26                                   City Place Hotel                  Hotel
# 27                                       Hotel Indigo                  Hotel
# 28                                  The Parkway Hotel                  Hotel
# 29                                 HoteLumière Atrium                  Hotel
# 30                   Millennium Hotel Cafe And Buffet                   Café
# 31                 Fitness Center at Millennium Hotel                    Gym
# 32                      Millennium Hotel Outdoor Pool             Hotel Pool
# 33                    Drury Plaza Hotel Exercise Room   Gym / Fitness Center
# 34                              Samuel Shephard Hotel                   None
# 35                             Hampton Inn Hotel Pool             Hotel Pool
# 36               8th Floor Lobby ~ Four Seasons Hotel                  Hotel
# 37                  Four Seasons Hotel Fitness Center   Gym / Fitness Center
# 38                         four season hotel roof top               Building
# 39  Cabana 1, Sky Terrace at Four Seasons Hotel St...  General Entertainment
# 40                 Four Seasons Hotel 6th Floor Lobby                  Hotel
# 41                                      Hotel Ignacio                  Hotel
# 42                                 Casino Queen Hotel                  Hotel
# 43                                   Angad Arts Hotel                  Hotel
# 44                Hyatt Regency St. Louis At The Arch                  Hotel
# 45                                             Hilton                  Hotel
# 46                                  Ford Hotel Supply                   Food
# 47                           Marriott St. Louis Grand                  Hotel
# 48                           Mahogany Grille & Lounge              Hotel Bar
# 49                                          Starbucks            Coffee Shop
#
#                      address       crossStreet        lat        lng  \
# 0              400 S 14th St            Spruce  38.624326 -90.202234
# 1             1820 Market St               NaN  38.628166 -90.207588
# 2               705 Olive St        7th Street  38.628497 -90.191609
# 3              Hirygoyen 600               NaN  38.626807 -90.202651
# 4               999 N 2nd St       at Carr St.  38.633727 -90.184993
# 5               999 N 2nd St               NaN  38.633489 -90.184542
# 6               999 N 2nd St               NaN  38.633187 -90.185338
# 7                 2 S 4th St               NaN  38.624846 -90.188981
# 8               501 Olive St               NaN  38.627940 -90.189320
# 9         800 Washington Ave               NaN  38.630499 -90.191722
# 10                       NaN               NaN  38.621268 -90.191474
# 11                       NaN               NaN  38.630399 -90.202554
# 12      421 North 8th Street               NaN  38.630072 -90.191999
# 13       1501 Washington Ave               NaN  38.632730 -90.200548
# 14                       NaN               NaN  38.629135 -90.207297
# 15         210 N Tucker Blvd              Pine  38.629679 -90.197149
# 16           2204 N Broadway               NaN  38.649087 -90.188034
# 17                       NaN               NaN  38.623180 -90.196663
# 18                       NaN               NaN  38.632717 -90.200638
# 19                       NaN               NaN  38.630499 -90.195995
# 20              205 N 9th St           Pine St  38.628448 -90.194504
# 21                       NaN               NaN  38.630416 -90.191373
# 22                       NaN               NaN  38.630649 -90.192929
# 23                       NaN               NaN  38.630929 -90.192606
# 24        800 Washington Ave        9th Street  38.630561 -90.192249
# 25        2625 Lafayette Ave               NaN  38.615963 -90.221985
# 26              200 N 4th St               NaN  38.627026 -90.187380
# 27         4630 Lindell Blvd               NaN  38.642669 -90.260789
# 28      4550 Forest Park Ave  at S Euclid Ave.  38.638684 -90.261744
# 29              999 N 2nd St               NaN  38.632319 -90.183718
# 30                       NaN               NaN  38.622850 -90.189701
# 31              400 S 4th St               NaN  38.621250 -90.189827
# 32                 200 W 4th               NaN  38.623557 -90.188527
# 33          2-98 Memorial Dr               NaN  38.624633 -90.188339
# 34                       NaN               NaN  38.636477 -90.214009
# 35                       NaN               NaN  38.629753 -90.184085
# 36                       NaN               NaN  38.633479 -90.184592
# 37                       NaN               NaN  38.633524 -90.184430
# 38                       NaN               NaN  38.633551 -90.184912
# 39              999 N 2nd St       Carr Street  38.633969 -90.184171
# 40                       NaN               NaN  38.633451 -90.184350
# 41             3411 Olive St               NaN  38.636744 -90.228581
# 42              200 Front St               NaN  38.626555 -90.174817
# 43  3550 Samuel T Shepard Dr               NaN  38.639630 -90.230600
# 44           315 Chestnut St               NaN  38.625908 -90.187671
# 45              1 S Broadway     at Market St.  38.625140 -90.190928
# 46           2204 N Broadway               NaN  38.647696 -90.188193
# 47        800 Washington Ave       at N 8th St  38.630542 -90.191908
# 48              1019 Pine St               NaN  38.628608 -90.195692
# 49           315 Chestnut St               NaN  38.625811 -90.187446
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 38.62432564742862...       278      63103
# 1   [{'label': 'display', 'lat': 38.6281661, 'lng'...       456      63103
# 2   [{'label': 'display', 'lat': 38.6284969, 'lng'...       977      63101
# 3   [{'label': 'display', 'lat': 38.62680659303982...         1      63103
# 4   [{'label': 'display', 'lat': 38.63372654049416...      1716      63102
# 5   [{'label': 'display', 'lat': 38.63348919160805...      1740      63102
# 6   [{'label': 'display', 'lat': 38.63318667, 'lng...      1663      63102
# 7   [{'label': 'display', 'lat': 38.62484625528558...      1207      63102
# 8   [{'label': 'display', 'lat': 38.62794, 'lng': ...      1165      63101
# 9   [{'label': 'display', 'lat': 38.63049889552403...      1034      63101
# 10  [{'label': 'display', 'lat': 38.62126754426016...      1150      63102
# 11  [{'label': 'display', 'lat': 38.63039850763389...       399        NaN
# 12  [{'label': 'display', 'lat': 38.6300716, 'lng'...       994      63101
# 13  [{'label': 'display', 'lat': 38.63272966631540...       683      63103
# 14  [{'label': 'display', 'lat': 38.629135, 'lng':...       480      63103
# 15  [{'label': 'display', 'lat': 38.6296791871398,...       574      63101
# 16  [{'label': 'display', 'lat': 38.64908683841786...      2786      63102
# 17  [{'label': 'display', 'lat': 38.6231803894043,...       658      63102
# 18  [{'label': 'display', 'lat': 38.632717, 'lng':...       680      63103
# 19  [{'label': 'display', 'lat': 38.6304988, 'lng'...       708        NaN
# 20  [{'label': 'display', 'lat': 38.62844848632812...       730      63101
# 21  [{'label': 'display', 'lat': 38.6304160501076,...      1058      63101
# 22  [{'label': 'display', 'lat': 38.63064917962153...       946        NaN
# 23  [{'label': 'display', 'lat': 38.630929, 'lng':...       985      63101
# 24  [{'label': 'display', 'lat': 38.630561, 'lng':...       995      63101
# 25  [{'label': 'display', 'lat': 38.61596298217773...      2070      63104
# 26  [{'label': 'display', 'lat': 38.627026, 'lng':...      1327      63102
# 27  [{'label': 'display', 'lat': 38.642669, 'lng':...      5355      63108
# 28  [{'label': 'display', 'lat': 38.63868380115087...      5306      63108
# 29  [{'label': 'display', 'lat': 38.63231867994509...      1756        NaN
# 30  [{'label': 'display', 'lat': 38.62285, 'lng': ...      1208      63102
# 31  [{'label': 'display', 'lat': 38.62125015258789...      1274      63102
# 32  [{'label': 'display', 'lat': 38.62355695397472...      1279        NaN
# 33  [{'label': 'display', 'lat': 38.62463321318748...      1266      63102
# 34  [{'label': 'display', 'lat': 38.63647688711329...      1461        NaN
# 35  [{'label': 'display', 'lat': 38.629753, 'lng':...      1646      63102
# 36  [{'label': 'display', 'lat': 38.63347947877371...      1736        NaN
# 37  [{'label': 'display', 'lat': 38.633524, 'lng':...      1751        NaN
# 38  [{'label': 'display', 'lat': 38.6335509373844,...      1714      63102
# 39  [{'label': 'display', 'lat': 38.63396940626958...      1792      63102
# 40  [{'label': 'display', 'lat': 38.63345126091753...      1753        NaN
# 41  [{'label': 'display', 'lat': 38.63674444515303...      2512      63103
# 42  [{'label': 'display', 'lat': 38.62655457190104...      2419      62201
# 43  [{'label': 'display', 'lat': 38.63963001520621...      2819      63103
# 44  [{'label': 'display', 'lat': 38.6259076372355,...      1305      63102
# 45  [{'label': 'display', 'lat': 38.62513965275549...      1035      63102
# 46  [{'label': 'display', 'lat': 38.64769595869986...      2642      63102
# 47  [{'label': 'display', 'lat': 38.63054246520622...      1021      63101
# 48  [{'label': 'display', 'lat': 38.62860785859991...       636      63101
# 49  [{'label': 'display', 'lat': 38.625811, 'lng':...      1325      63102
#
#     cc              city     state        country  \
# 0   US          St Louis        MO  United States
# 1   US          St Louis        MO  United States
# 2   US          St Louis        MO  United States
# 3   US       Justo Darac        MO  United States
# 4   US          St Louis        MO  United States
# 5   US          St Louis        MO  United States
# 6   US          St Louis        MO  United States
# 7   US          St Louis        MO  United States
# 8   US          St Louis        MO  United States
# 9   US          St Louis        MO  United States
# 10  US          St Louis        MO  United States
# 11  US          St Louis        MO  United States
# 12  US          St Louis        MO  United States
# 13  US          St Louis        MO  United States
# 14  US          St Louis        MO  United States
# 15  US          St Louis        MO  United States
# 16  US          St Louis        MO  United States
# 17  US          St Louis        MO  United States
# 18  US          St Louis        MO  United States
# 19  US               NaN  Missouri  United States
# 20  US          St Louis        MO  United States
# 21  US          St Louis        MO  United States
# 22  US               NaN  Missouri  United States
# 23  US          St Louis        MO  United States
# 24  US          St Louis        MO  United States
# 25  US          St Louis        MO  United States
# 26  US          St Louis        MO  United States
# 27  US          St Louis        MO  United States
# 28  US          St Louis        MO  United States
# 29  US          St Louis        IL  United States
# 30  US          St Louis        MO  United States
# 31  US          St Louis        MO  United States
# 32  US          St Louis        MO  United States
# 33  US          St Louis        MO  United States
# 34  US          St Louis        MO  United States
# 35  US          St Louis        MO  United States
# 36  US          St Louis        MO  United States
# 37  US          St Louis        MO  United States
# 38  US          St Louis        MO  United States
# 39  US          St Louis        MO  United States
# 40  US          St Louis        MO  United States
# 41  US          St Louis        MO  United States
# 42  US  East Saint Louis        IL  United States
# 43  US          St Louis        MO  United States
# 44  US          St Louis        MO  United States
# 45  US          St Louis        MO  United States
# 46  US          St Louis        MO  United States
# 47  US          St Louis        MO  United States
# 48  US          St Louis        MO  United States
# 49  US          St Louis        MO  United States
#
#                                      formattedAddress   neighborhood  \
# 0   [400 S 14th St (Spruce), St Louis, MO 63103, U...            NaN
# 1   [1820 Market St, St Louis, MO 63103, United St...            NaN
# 2   [705 Olive St (7th Street), St Louis, MO 63101...            NaN
# 3   [Hirygoyen 600, Justo Darac, MO 63103, United ...            NaN
# 4   [999 N 2nd St (at Carr St.), St Louis, MO 6310...            NaN
# 5   [999 N 2nd St, St Louis, MO 63102, United States]            NaN
# 6   [999 N 2nd St, St Louis, MO 63102, United States]            NaN
# 7     [2 S 4th St, St Louis, MO 63102, United States]            NaN
# 8   [501 Olive St, St Louis, MO 63101, United States]            NaN
# 9   [800 Washington Ave, St Louis, MO 63101, Unite...            NaN
# 10                [St Louis, MO 63102, United States]  Downtown East
# 11                      [St Louis, MO, United States]            NaN
# 12  [421 North 8th Street, St Louis, MO 63101, Uni...            NaN
# 13  [1501 Washington Ave, St Louis, MO 63103, Unit...            NaN
# 14                [St Louis, MO 63103, United States]            NaN
# 15  [210 N Tucker Blvd (Pine), St Louis, MO 63101,...            NaN
# 16  [2204 N Broadway, St Louis, MO 63102, United S...            NaN
# 17                [St Louis, MO 63102, United States]            NaN
# 18                [St Louis, MO 63103, United States]            NaN
# 19                          [Missouri, United States]            NaN
# 20  [205 N 9th St (Pine St), St Louis, MO 63101, U...            NaN
# 21                [St Louis, MO 63101, United States]            NaN
# 22                          [Missouri, United States]            NaN
# 23                [St Louis, MO 63101, United States]            NaN
# 24  [800 Washington Ave (9th Street), St Louis, MO...            NaN
# 25  [2625 Lafayette Ave, St Louis, MO 63104, Unite...            NaN
# 26  [200 N 4th St, St Louis, MO 63102, United States]            NaN
# 27  [4630 Lindell Blvd, St Louis, MO 63108, United...            NaN
# 28  [4550 Forest Park Ave (at S Euclid Ave.), St L...            NaN
# 29        [999 N 2nd St, St Louis, IL, United States]            NaN
# 30                [St Louis, MO 63102, United States]            NaN
# 31  [400 S 4th St, St Louis, MO 63102, United States]            NaN
# 32           [200 W 4th, St Louis, MO, United States]            NaN
# 33  [2-98 Memorial Dr, St Louis, MO 63102, United ...            NaN
# 34                      [St Louis, MO, United States]            NaN
# 35                [St Louis, MO 63102, United States]            NaN
# 36                      [St Louis, MO, United States]            NaN
# 37                      [St Louis, MO, United States]            NaN
# 38                [St Louis, MO 63102, United States]            NaN
# 39  [999 N 2nd St (Carr Street), St Louis, MO 6310...            NaN
# 40                      [St Louis, MO, United States]            NaN
# 41  [3411 Olive St, St Louis, MO 63103, United Sta...            NaN
# 42  [200 Front St, East Saint Louis, IL 62201, Uni...            NaN
# 43  [3550 Samuel T Shepard Dr, St Louis, MO 63103,...            NaN
# 44  [315 Chestnut St, St Louis, MO 63102, United S...            NaN
# 45  [1 S Broadway (at Market St.), St Louis, MO 63...            NaN
# 46  [2204 N Broadway, St Louis, MO 63102, United S...            NaN
# 47  [800 Washington Ave (at N 8th St), St Louis, M...            NaN
# 48  [1019 Pine St, St Louis, MO 63101, United States]            NaN
# 49  [315 Chestnut St, St Louis, MO 63102, United S...            NaN
#
#                           id
# 0   54aabce9498ee74ea1c8d10b
# 1   508de513e4b09f7bba74e3bb
# 2   59e694bf98fbfc0ac5ddf8e9
# 3   50375451e4b0df99d53c13fe
# 4   4b0ff2aff964a520a36623e3
# 5   4b6b5c99f964a52081032ce3
# 6   4acbc3f9f964a5207ec520e3
# 7   4acbc3f9f964a52078c520e3
# 8   5ca465cac5b11c002c010408
# 9   4dc8c220e4cdf14b85507cef
# 10  4c2ab1888abca5938824ff1f
# 11  4c79c3f781bca09326b8fe14
# 12  53f2954a498e248b534eda30
# 13  5d11afbe96effb0023a494a4
# 14  5b4106609411f2002cbf5295
# 15  4ae5b3a5f964a52090a121e3
# 16  5011702b45b09001ecec1f29
# 17  4fb15a5ce4b0fd09aa1850c2
# 18  5e4361fcdfa35f0008124e83
# 19  4e3847a88877541e90edf963
# 20  50e5053be4b0514cab710f41
# 21  4ea2bc8777c8d0ce5e0ed2ab
# 22  4f5d203fe4b0a61f4cab854a
# 23  5756c5e3498eb346a8016811
# 24  4ed46bcc93ad512d8d68c0ab
# 25  57da0008498ec00cda120d7d
# 26  591673bad552c72b8cd36b0e
# 27  4b0f356af964a5206b6023e3
# 28  4b4a4c3ef964a520cf8226e3
# 29  5189449f498ecc6fb8dc3471
# 30  4e11dedbaeb74afe60c0ab43
# 31  4c66e172b80abe9a4a4acee5
# 32  4c3539ce66e40f471ff6ca8b
# 33  4ce6b1a3e888f04dc799376b
# 34  4df39d961f6e818dae014e80
# 35  5a1404928ad62e7497e0a279
# 36  53504da6498e406e709aa8b6
# 37  55135419498e3b5627966d1c
# 38  4fdbe627e4b0602ab5a063ee
# 39  4df2308b3151247c51af65e0
# 40  4ea5fcd830f8a6425ee8bbd4
# 41  4d9b29fcc67f2c0f036248af
# 42  4c7f7576d860b60c37dc609d
# 43  5aa349efacc5f55cdf29c15e
# 44  4af73b36f964a520780722e3
# 45  4acbc3f9f964a5207fc520e3
# 46  4f436f7519834bc91f56d2a9
# 47  4ae84525f964a52068ae21e3
# 48  4bb364ec14cfd13a16f315ab
# 49  4ae6f0a9f964a520a1a721e3

# %%
dataframe_filtered.name
# Out:
# 0                              Red Lion Hotel St. Louis
# 1     St. Louis Union Station Hotel, Curio Collectio...
# 2               Hotel Saint Louis, Autograph Collection
# 3                                        Hotel El Pocho
# 4                                    Four Seasons Hotel
# 5                   Spa at Four Seasons Hotel St. Louis
# 6                          Lumiere Place Casino & Hotel
# 7               Drury Plaza Hotel St. Louis At The Arch
# 8                                          Hotel Indigo
# 9     Renaissance St. Louis Grand Hotel - Fitness Ce...
# 10                           Millennium Hotel St. Louis
# 11               Renaissance Grand Hotel Parking Garage
# 12                                       Magnolia Hotel
# 13                                       The Last Hotel
# 14                        Union Station Hotel Gift Shop
# 15                                   Data Carrier Hotel
# 16                     Ford Hotel Supply Co - St. Louis
# 17                        cupples Ballroom Westin Hotel
# 18                                   The Last Hotel Gym
# 19                            Living At The Hotel Gibby
# 20                                     Mark Twain Hotel
# 21                                 Hotel Fitness Center
# 22         Renaissance Hotel St. Louis Crystal Ballroom
# 23                             Lennox Hotel 1929 portal
# 24    AFA Annual Meeting (Renaissance St. Louis Gran...
# 25                                          Hotel Avyan
# 26                                     City Place Hotel
# 27                                         Hotel Indigo
# 28                                    The Parkway Hotel
# 29                                   HoteLumière Atrium
# 30                     Millennium Hotel Cafe And Buffet
# 31                   Fitness Center at Millennium Hotel
# 32                        Millennium Hotel Outdoor Pool
# 33                      Drury Plaza Hotel Exercise Room
# 34                                Samuel Shephard Hotel
# 35                               Hampton Inn Hotel Pool
# 36                 8th Floor Lobby ~ Four Seasons Hotel
# 37                    Four Seasons Hotel Fitness Center
# 38                           four season hotel roof top
# 39    Cabana 1, Sky Terrace at Four Seasons Hotel St...
# 40                   Four Seasons Hotel 6th Floor Lobby
# 41                                        Hotel Ignacio
# 42                                   Casino Queen Hotel
# 43                                     Angad Arts Hotel
# 44                  Hyatt Regency St. Louis At The Arch
# 45                                               Hilton
# 46                                    Ford Hotel Supply
# 47                             Marriott St. Louis Grand
# 48                             Mahogany Grille & Lounge
# 49                                            Starbucks
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Home',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
